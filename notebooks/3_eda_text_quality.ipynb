# %% [markdown]
# # Initial Path and libraries

# %%
import pandas as pd
from pathlib import Path


PROJECT_ROOT = Path.cwd()
PROCESSED = PROJECT_ROOT / "data" / "processed"

# %% [markdown]
# # Reviews_enriched

# %% [markdown]
# ## Dataset

# %%
path = PROCESSED / "reviews_enriched.parquet"
reviews_enriched_df = pd.read_parquet(path, engine="pyarrow")
print(reviews_enriched_df.shape)
reviews_enriched_df.describe()
# Out:
# (98410, 22)
#        review_score    bad_review           review_creation_date  \
# count  98410.000000  98410.000000                          98410
# mean       4.088802      0.146286  2018-01-13 06:50:35.984147968
# min        1.000000      0.000000            2016-10-02 00:00:00
# 25%        4.000000      0.000000            2017-09-24 00:00:00
# 50%        5.000000      0.000000            2018-02-02 00:00:00
# 75%        5.000000      0.000000            2018-05-16 00:00:00
# max        5.000000      1.000000            2018-08-31 00:00:00
# std        1.345758      0.353394                            NaN
#
#              review_answer_timestamp  response_time_days   text_length  \
# count                          98410        98410.000000  98410.000000
# mean   2018-01-16 10:26:43.416786944            3.150086     28.350401
# min              2016-10-07 18:32:28            0.089225      0.000000
# 25%       2017-09-27 19:43:43.500000            1.004499      0.000000
# 50%              2018-02-05 11:08:52            1.673993      0.000000
# 75%    2018-05-20 14:08:15.750000128            3.102049     42.000000
# max              2018-10-29 12:27:35          518.699213    208.000000
# std                              NaN            9.914724     48.354100
#
#        order_delivered_customer_date  order_estimated_delivery_date  \
# count                          95601                          98410
# mean   2018-01-14 18:28:20.021411840  2018-01-24 08:57:59.939030784
# min              2016-10-11 13:46:32            2016-09-30 00:00:00
# 25%              2017-09-26 16:48:01            2017-10-04 00:00:00
# 50%              2018-02-02 21:33:45            2018-02-15 00:00:00
# 75%              2018-05-16 13:45:48            2018-05-28 00:00:00
# max              2018-10-17 13:22:46            2018-11-12 00:00:00
# std                              NaN                            NaN
#
#        delivery_delay_days  payment_installments  payment_value  \
# count         95601.000000          98409.000000   98409.000000
# mean            -11.212855              2.927253     160.719938
# min            -146.016123              0.000000       0.000000
# 25%             -16.247558              1.000000      61.960000
# 50%             -11.963137              2.000000     105.280000
# 75%              -6.405116              4.000000     176.830000
# max             188.975081             24.000000   13664.080000
# std              10.108965              2.713002     220.426067
#
#        response_time_negative  is_delivered  has_delivery_delay
# count                 98410.0  98410.000000        98410.000000
# mean                      0.0      0.971476            0.971456
# min                       0.0      0.000000            0.000000
# 25%                       0.0      1.000000            1.000000
# 50%                       0.0      1.000000            1.000000
# 75%                       0.0      1.000000            1.000000
# max                       0.0      1.000000            1.000000
# std                       0.0      0.166464            0.166521

# %%
cols_needed = [
    "review_id",
    "order_id",
    "review_score",
    "bad_review",
    "has_text",
    "text_length",
    "text_clean",
    "review_creation_date",
]
print("review_id unique:", reviews_enriched_df["review_id"].is_unique)
print(
    reviews_enriched_df[cols_needed].isna().mean().sort_values(ascending=False).head(10)
)
# Out:
# review_id unique: True
# review_id               0.0
# order_id                0.0
# review_score            0.0
# bad_review              0.0
# has_text                0.0
# text_length             0.0
# text_clean              0.0
# review_creation_date    0.0
# dtype: float64

# %% [markdown]
# ## % of has_text

# %%
has_text_porcentage = (reviews_enriched_df["has_text"]).mean() * 100
no_text_porcentage = 100 - has_text_porcentage
print("% of reviews without comments", no_text_porcentage)
print("% of reviews with comments", has_text_porcentage)
print("Count:", reviews_enriched_df["has_text"].value_counts(dropna=False))
# Out:
# % of reviews without comments 58.70236764556447
# % of reviews with comments 41.29763235443553
# Count: has_text
# False    57769
# True     40641
# Name: count, dtype: int64

# %% [markdown]
# Approximately 4 out of 10 reviews contain text, so any sentiment/text analysis is perfomed on this subset

# %% [markdown]
# ## Usable text: is there text in all rows or is there an empty string?

# %%
reviews_enriched_df["text_clean"] = reviews_enriched_df["text_clean"].fillna("")
reviews_enriched_df["text_clean_len"] = reviews_enriched_df["text_clean"].str.len()

usable_text = reviews_enriched_df["text_clean_len"] > 0
print("Usable text %:", (usable_text.mean() * 100))
usable_text
# Out:
# Usable text %: 41.29763235443553
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 98405    False
# 98406    False
# 98407     True
# 98408    False
# 98409    False
# Name: text_clean_len, Length: 98410, dtype: bool

# %% [markdown]
# ## Distribution of text_length

# %%
print(reviews_enriched_df["text_length"].describe())
# Out:
# count    98410.000000
# mean        28.350401
# std         48.354100
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         42.000000
# max        208.000000
# Name: text_length, dtype: float64

# %%
df_text = reviews_enriched_df[reviews_enriched_df["has_text"]].copy()
print("\ntext_length describe (has_text=True):")
print(df_text["text_length"].describe())

# short text proportions
for k in [1, 3, 5, 10, 20, 30]:
    pct = (df_text["text_length"] <= k).mean() * 100
    print(f"<= {k} chars: {pct:.2f}%")
# Out:
# text_length describe (has_text=True):
# count    40641.000000
# mean        68.647277
# std         53.808996
# min          1.000000
# 25%         28.000000
# 50%         53.000000
# 75%         95.000000
# max        208.000000
# Name: text_length, dtype: float64
# <= 1 chars: 0.23%
# <= 3 chars: 1.85%
# <= 5 chars: 3.25%
# <= 10 chars: 8.58%
# <= 20 chars: 17.45%
# <= 30 chars: 27.57%

# %% [markdown]
# ## Bad reviews:

# %%
print("Bad review overall:")
print(reviews_enriched_df["bad_review"].value_counts(normalize=True).mul(100).round(2))

print("\nBad review with has_text=True:")
print(df_text["bad_review"].value_counts(normalize=True).mul(100).round(2))
# Out:
# Bad review overall:
# bad_review
# 0    85.37
# 1    14.63
# Name: proportion, dtype: float64
#
# Bad review with has_text=True:
# bad_review
# 0    73.53
# 1    26.47
# Name: proportion, dtype: float64

# %% [markdown]
# ## Crosstable: review_score x has_text

# %%
import pandas as pd

tab = (
    pd.crosstab(
        reviews_enriched_df["review_score"],
        reviews_enriched_df["has_text"],
        normalize="index",
    )
    * 100
)
tab = tab.round(2)
tab
# Out:
# has_text      False  True
# review_score
# 1             23.42  76.58
# 2             31.98  68.02
# 3             56.43  43.57
# 4             68.77  31.23
# 5             64.12  35.88

# %% [markdown]
# ## Example large/short texts

# %%
short_text = df_text.sort_values("text_length").head(10)[
    [
        "review_score",
        "bad_review",
        "text_length",
        "review_comment_message",
        "text_clean",
    ]
]
short_text
# Out:
#        review_score  bad_review  text_length review_comment_message text_clean
# 32183             5           0            1                      *          *
# 24692             5           0            1                      s          s
# 72418             4           0            1                      S          s
# 11264             5           0            1                      .          .
# 90053             4           0            1                      .          .
# 51705             4           0            1                      s          s
# 70690             5           0            1                      K          k
# 75115             5           0            1                      😀          😀
# 66892             4           0            1                      -          -
# 79154             4           0            1                      ?          ?

# %%
long_text = df_text.sort_values("text_length", ascending=False).head(10)[
    [
        "review_score",
        "bad_review",
        "text_length",
        "review_comment_message",
        "text_clean",
    ]
]
long_text
# Out:
#        review_score  bad_review  text_length  \
# 6889              1           1          208
# 23188             4           0          207
# 76645             1           1          206
# 78379             1           1          205
# 21242             1           1          204
# 16417             5           0          204
# 19979             1           1          204
# 30448             4           0          204
# 20056             3           0          204
# 40739             1           1          204
#
#                                   review_comment_message  \
# 6889   NÃO RECEBI O PRODUTO, O PRODUTO CONSTA COMO EN...
# 23188  Adquiri 2 mochilas pelo site lannister de e pa...
# 76645  Comprei o produto confiando nas lojas lanniste...
# 78379  fiz essa compra pelo baratheon comprei um conj...
# 21242  Na minha compra realizada em 20/09/17 a loja t...
# 16417  Parabéns ,o produto tira rico da empresa targa...
# 19979  A targaryen não é de confiança não entregou a ...
# 30448  O produto cumpre totalmente com o que o fabric...
# 20056  Não Montei ele ainda mais pelo que conferi est...
# 40739  A EMPRESA FAZ PROPAGANDA ENGANOSA EM SEU SITE....
#
#                                               text_clean
# 6889   não recebi o produto, o produto consta como en...
# 23188  adquiri 2 mochilas pelo site lannister de e pa...
# 76645  comprei o produto confiando nas lojas lanniste...
# 78379  fiz essa compra pelo baratheon comprei um conj...
# 21242  na minha compra realizada em 20/09/17 a loja t...
# 16417  parabéns ,o produto tira rico da empresa targa...
# 19979  a targaryen não é de confiança não entregou a ...
# 30448  o produto cumpre totalmente com o que o fabric...
# 20056  não montei ele ainda mais pelo que conferi est...
# 40739  a empresa faz propaganda enganosa em seu site....

# %% [markdown]
# ## top words

# %% [markdown]
# ### Import nltk and CountVectorizer

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

nltk.download("stopwords")
portuguese_stopword = stopwords.words("portuguese")

# %% [markdown]
# ### frequency and vocabulary without stopwords

# %%
sample = reviews_enriched_df["text_clean"].fillna("")
# words that appear at least 20 times(inside reviews)
cv = CountVectorizer(min_df=20, stop_words=portuguese_stopword)
X = cv.fit_transform(sample)

frequency = X.sum(axis=0).A1
vocabulary = cv.get_feature_names_out()

word_frequency = pd.Series(frequency, index=vocabulary).sort_values(ascending=False)
word_frequency.head(10)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jesus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# produto      18289
# prazo         8431
# entrega       6482
# antes         5605
# chegou        5523
# recebi        5210
# bom           4573
# recomendo     4314
# entregue      3753
# veio          3250
# dtype: int64
